# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 7.7 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 89.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 113.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 KB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.4 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ## Settings and run

# %%
#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/menvickkey" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# Mounted at /content/drive
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/menvickkey

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
    {
        "instance_prompt":      "menvickkey",
        "class_prompt":         "person",
        "instance_data_dir":    "/content/data/menvickkey",
        "class_data_dir":       "/content/data/person"
    },
#     {
#         "instance_prompt":      "photo of ukj person",
#         "class_prompt":         "photo of a person",
#         "instance_data_dir":    "/content/data/ukj",
#         "class_data_dir":       "/content/data/person"
#     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to each `instance_data_dir` (it uploads faster)

import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=1000 \
  --save_interval=10000 \
  --save_sample_prompt="photo of menvickkey" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# WARNING:accelerate.commands.launch:The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading (…)_model.safetensors";: 100% 335M/335M [00:01<00:00, 202MB/s]
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 89.4kB/s]
# Downloading (…)p16/model_index.json: 100% 543/543 [00:00<00:00, 90.2kB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (…)"pytorch_model.bin";:   0% 0.00/608M [00:00<?, ?B/s]
#
# Downloading (…)"pytorch_model.bin";:   0% 0.00/246M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   3% 21.0M/608M [00:00<00:03, 162MB/s]
#
# Downloading (…)"pytorch_model.bin";:   9% 21.0M/246M [00:00<00:01, 156MB/s]
#
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 24.3kB/s]
#
#
#
# Downloading (…)_checker/config.json:   0% 0.00/4.70k [00:00<?, ?B/s]
#
#
#
# Downloading (…)cheduler_config.json: 100% 307/307 [00:00<00:00, 37.8kB/s]
#
#
#
#
# Downloading (…)cial_tokens_map.json:   0% 0.00/472 [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)_encoder/config.json:   0% 0.00/636 [00:00<?, ?B/s]
#
#
#
#
#
# Downloading (…)_checker/config.json: 100% 4.70k/4.70k [00:00<00:00, 78.0kB/s]
# Downloading (…)_encoder/config.json: 100% 636/636 [00:00<00:00, 25.8kB/s]
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 13.3kB/s]
#
# Downloading (…)"pytorch_model.bin";:   7% 41.9M/608M [00:00<00:04, 126MB/s]
#
# Downloading (…)"pytorch_model.bin";:  17% 41.9M/246M [00:00<00:01, 130MB/s]
#
# Downloading (…)"pytorch_model.bin";:  26% 62.9M/246M [00:00<00:01, 157MB/s]
# Downloading (…)"pytorch_model.bin";:  10% 62.9M/608M [00:00<00:03, 147MB/s]
#
# Downloading (…)"pytorch_model.bin";:  38% 94.4M/246M [00:00<00:00, 172MB/s]
#
#
#
#
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 1.53MB/s]
#
# Downloading (…)"pytorch_model.bin";:  14% 83.9M/608M [00:00<00:03, 133MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   0% 0.00/1.72G [00:00<?, ?B/s]
#
# Downloading (…)"pytorch_model.bin";:  47% 115M/246M [00:00<00:00, 161MB/s]
# Downloading (…)"pytorch_model.bin";:  17% 105M/608M [00:00<00:03, 130MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   1% 21.0M/1.72G [00:00<00:11, 143MB/s]
#
#
#
# Downloading (…)okenizer_config.json: 100% 822/822 [00:00<00:00, 258kB/s]
#
#
# Downloading (…)"pytorch_model.bin";:  55% 136M/246M [00:00<00:00, 165MB/s]
#
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)cc2/unet/config.json: 100% 806/806 [00:00<00:00, 196kB/s]
#
#
#
#
#
# Downloading (…)9cc2/vae/config.json: 100% 609/609 [00:00<00:00, 96.2kB/s]
#
# Downloading (…)"pytorch_model.bin";:  21% 126M/608M [00:01<00:04, 109MB/s]
#
# Downloading (…)"pytorch_model.bin";:  64% 157M/246M [00:01<00:00, 142MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   2% 41.9M/1.72G [00:00<00:16, 104MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:   6% 10.5M/167M [00:00<00:02, 73.0MB/s]
# Downloading (…)"pytorch_model.bin";:  24% 147M/608M [00:01<00:04, 102MB/s]
#
# Downloading (…)"pytorch_model.bin";:  72% 178M/246M [00:01<00:00, 122MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   4% 62.9M/1.72G [00:00<00:16, 99.6MB/s]
#
#
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 2.68MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  13% 21.0M/167M [00:00<00:02, 67.4MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   5% 83.9M/1.72G [00:00<00:15, 102MB/s]
# Downloading (…)"pytorch_model.bin";:  28% 168M/608M [00:01<00:04, 94.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  81% 199M/246M [00:01<00:00, 106MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  19% 31.5M/167M [00:00<00:02, 62.7MB/s]
# Downloading (…)"pytorch_model.bin";:  29% 178M/608M [00:01<00:04, 92.8MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   6% 105M/1.72G [00:01<00:15, 104MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  25% 41.9M/167M [00:00<00:01, 70.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  89% 220M/246M [00:01<00:00, 107MB/s]
# Downloading (…)"pytorch_model.bin";:  31% 189M/608M [00:01<00:04, 90.0MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  31% 52.4M/167M [00:00<00:01, 71.7MB/s]
# Downloading (…)"pytorch_model.bin";:  33% 199M/608M [00:01<00:04, 86.3MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  38% 62.9M/167M [00:00<00:01, 74.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  98% 241M/246M [00:01<00:00, 98.2MB/s]
# Downloading (…)"pytorch_model.bin";:  34% 210M/608M [00:02<00:04, 86.9MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   7% 126M/1.72G [00:01<00:19, 83.4MB/s]
#
#
#
#
# Downloading (…)"pytorch_model.bin";: 100% 246M/246M [00:02<00:00, 118MB/s]
#
# Downloading (…)"pytorch_model.bin";:  36% 220M/608M [00:02<00:04, 87.3MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   8% 136M/1.72G [00:01<00:18, 84.8MB/s]
# Downloading (…)"pytorch_model.bin";:  38% 231M/608M [00:02<00:05, 71.8MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  56% 94.4M/167M [00:01<00:01, 66.1MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:   9% 147M/1.72G [00:01<00:24, 63.5MB/s]
# Downloading (…)"pytorch_model.bin";:  40% 241M/608M [00:02<00:04, 75.1MB/s]
# Downloading (…)"pytorch_model.bin";:  41% 252M/608M [00:02<00:04, 78.9MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  10% 168M/1.72G [00:01<00:20, 77.5MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  69% 115M/167M [00:01<00:00, 79.1MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  10% 178M/1.72G [00:02<00:19, 80.1MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  75% 126M/167M [00:01<00:00, 81.4MB/s]
# Downloading (…)"pytorch_model.bin";:  45% 273M/608M [00:02<00:03, 88.2MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  81% 136M/167M [00:01<00:00, 86.1MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  11% 189M/1.72G [00:02<00:18, 80.8MB/s]
# Downloading (…)"pytorch_model.bin";:  47% 283M/608M [00:02<00:03, 91.0MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  88% 147M/167M [00:01<00:00, 89.2MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  12% 199M/1.72G [00:02<00:18, 84.0MB/s]
# Downloading (…)"pytorch_model.bin";:  48% 294M/608M [00:03<00:03, 86.7MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  94% 157M/167M [00:02<00:00, 77.6MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  12% 210M/1.72G [00:02<00:19, 75.6MB/s]
# Downloading (…)"pytorch_model.bin";:  50% 304M/608M [00:03<00:03, 76.5MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";: 100% 167M/167M [00:02<00:00, 81.4MB/s]
#
#
# Downloading (…)_pytorch_model.bin";: 100% 167M/167M [00:02<00:00, 75.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  53% 325M/608M [00:03<00:03, 90.8MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  14% 241M/1.72G [00:02<00:15, 94.4MB/s]
# Downloading (…)"pytorch_model.bin";:  55% 336M/608M [00:03<00:02, 91.9MB/s]
# Downloading (…)"pytorch_model.bin";:  57% 346M/608M [00:03<00:02, 90.2MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  15% 262M/1.72G [00:02<00:15, 96.0MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  16% 273M/1.72G [00:03<00:15, 94.3MB/s]
# Downloading (…)"pytorch_model.bin";:  60% 367M/608M [00:03<00:02, 97.9MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  17% 294M/1.72G [00:03<00:13, 102MB/s]
# Downloading (…)"pytorch_model.bin";:  64% 388M/608M [00:04<00:02, 104MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  18% 304M/1.72G [00:03<00:13, 102MB/s]
# Downloading (…)"pytorch_model.bin";:  67% 409M/608M [00:04<00:01, 103MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  19% 325M/1.72G [00:03<00:13, 106MB/s]
# Downloading (…)"pytorch_model.bin";:  71% 430M/608M [00:04<00:01, 110MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  20% 346M/1.72G [00:03<00:12, 112MB/s]
# Downloading (…)"pytorch_model.bin";:  74% 451M/608M [00:04<00:01, 109MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  21% 367M/1.72G [00:03<00:12, 112MB/s]
# Downloading (…)"pytorch_model.bin";:  78% 472M/608M [00:04<00:01, 110MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  23% 388M/1.72G [00:04<00:12, 106MB/s]
# Downloading (…)"pytorch_model.bin";:  81% 493M/608M [00:04<00:01, 112MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  24% 409M/1.72G [00:04<00:12, 107MB/s]
# Downloading (…)"pytorch_model.bin";:  84% 514M/608M [00:05<00:00, 117MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  25% 430M/1.72G [00:04<00:11, 113MB/s]
# Downloading (…)"pytorch_model.bin";:  88% 535M/608M [00:05<00:00, 106MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  26% 451M/1.72G [00:04<00:11, 106MB/s]
# Downloading (…)"pytorch_model.bin";:  91% 556M/608M [00:05<00:00, 122MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  27% 472M/1.72G [00:04<00:10, 122MB/s]
# Downloading (…)"pytorch_model.bin";:  95% 577M/608M [00:05<00:00, 131MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  29% 493M/1.72G [00:04<00:09, 131MB/s]
# Downloading (…)"pytorch_model.bin";: 100% 608M/608M [00:05<00:00, 104MB/s]
# Fetching 15 files:  27% 4/15 [00:06<00:17,  1.62s/it]
#
#
# Downloading (…)_pytorch_model.bin";:  30% 514M/1.72G [00:05<00:10, 120MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  32% 545M/1.72G [00:05<00:07, 153MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  34% 577M/1.72G [00:05<00:07, 160MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  35% 598M/1.72G [00:05<00:06, 161MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  37% 629M/1.72G [00:05<00:05, 189MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  38% 650M/1.72G [00:05<00:05, 185MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  39% 671M/1.72G [00:05<00:06, 167MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  41% 703M/1.72G [00:06<00:05, 189MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  43% 734M/1.72G [00:06<00:04, 203MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  45% 765M/1.72G [00:06<00:04, 222MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  46% 797M/1.72G [00:06<00:04, 218MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  48% 828M/1.72G [00:06<00:03, 235MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  50% 860M/1.72G [00:06<00:03, 240MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  52% 891M/1.72G [00:06<00:03, 239MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  54% 923M/1.72G [00:07<00:03, 233MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  55% 954M/1.72G [00:07<00:04, 177MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  57% 975M/1.72G [00:07<00:04, 173MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  58% 996M/1.72G [00:07<00:04, 179MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  59% 1.02G/1.72G [00:07<00:03, 181MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  61% 1.05G/1.72G [00:07<00:03, 200MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  63% 1.08G/1.72G [00:07<00:02, 219MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  65% 1.11G/1.72G [00:08<00:03, 190MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  66% 1.13G/1.72G [00:08<00:03, 160MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  67% 1.15G/1.72G [00:08<00:03, 158MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  68% 1.17G/1.72G [00:08<00:04, 131MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  70% 1.20G/1.72G [00:08<00:03, 140MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  71% 1.22G/1.72G [00:08<00:03, 154MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  73% 1.25G/1.72G [00:10<00:09, 49.8MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  74% 1.27G/1.72G [00:10<00:07, 60.7MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  76% 1.30G/1.72G [00:10<00:05, 79.4MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  77% 1.33G/1.72G [00:10<00:03, 99.9MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  79% 1.36G/1.72G [00:10<00:02, 123MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  81% 1.39G/1.72G [00:10<00:02, 148MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  82% 1.42G/1.72G [00:11<00:02, 116MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  84% 1.44G/1.72G [00:11<00:02, 122MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  85% 1.47G/1.72G [00:11<00:01, 144MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  87% 1.49G/1.72G [00:11<00:01, 153MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  88% 1.52G/1.72G [00:11<00:01, 181MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  90% 1.55G/1.72G [00:11<00:00, 196MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  92% 1.58G/1.72G [00:12<00:00, 213MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  94% 1.61G/1.72G [00:12<00:00, 230MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  96% 1.65G/1.72G [00:12<00:00, 238MB/s]
#
#
# Downloading (…)_pytorch_model.bin";:  98% 1.69G/1.72G [00:12<00:00, 252MB/s]
#
#
# Downloading (…)_pytorch_model.bin";: 100% 1.72G/1.72G [00:12<00:00, 137MB/s]
# Fetching 15 files: 100% 15/15 [00:13<00:00,  1.10it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Generating class images: 100% 13/13 [03:10<00:00, 14.62s/it]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 2.85MB/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 1.69MB/s]
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 153kB/s]
# Downloading (…)okenizer_config.json: 100% 822/822 [00:00<00:00, 278kB/s]
# Downloading (…)_encoder/config.json: 100% 636/636 [00:00<00:00, 217kB/s]
# Downloading (…)"pytorch_model.bin";: 100% 246M/246M [00:01<00:00, 195MB/s]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 112
# CUDA SETUP: Loading binary /usr/local/lib/python3.8/dist-packages/bitsandbytes/libbitsandbytes_cuda112.so...
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 92.7kB/s]
# Caching latents: 100% 98/98 [00:19<00:00,  4.95it/s]
# Steps: 100% 1000/1000 [12:30<00:00,  1.35it/s, loss=0.314, lr=1e-6]
# Fetching 15 files: 100% 15/15 [00:00<00:00, 28688.81it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:07<00:22,  7.40s/it]
# Generating samples:  50% 2/4 [00:11<00:10,  5.29s/it]
# Generating samples:  75% 3/4 [00:15<00:04,  4.61s/it]
# Generating samples: 100% 4/4 [00:18<00:00,  4.72s/it]
# [*] Weights saved at /content/drive/MyDrive/stable_diffusion_weights/menvickkey/1000
# Steps: 100% 1000/1000 [13:13<00:00,  1.26it/s, loss=0.314, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/stable_diffusion_weights/menvickkey/1000

# %%
#@markdown Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')
        
plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/menvickkey/1000/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None
# Out:
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 53362 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "menvickkey person, modern young man with ash blond hair, open and undone jeans, age appropriate,  intricate, simple, highly detailed, lighting, artstation, smooth, illustration, art by greg rutowski and alphonse mucha" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 24 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6F95ADB370>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6F95ADB760>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6F95ADBFD0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6F95AF4820>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=24)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
